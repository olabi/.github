# %%
import pandas as pd

# %%
# %%time
df=pd.read_csv("/kaggle/input/ninapro-db1-full-dataset/Ninapro_DB1.csv")
# Out:
# CPU times: user 1min 2s, sys: 4.78 s, total: 1min 7s
# Wall time: 1min 25s

# %%
import cudf

# %%
# %%time
df=cudf.read_csv("/kaggle/input/ninapro-db1-full-dataset/Ninapro_DB1.csv")
# Out:
# CPU times: user 2.99 s, sys: 2.03 s, total: 5.01 s
# Wall time: 30.9 s
